# %%
from selenium import webdriver
from tqdm import tqdm

# %%
from selenium.webdriver.common.by import By

# %%
options = webdriver.EdgeOptions()

# %%
options.add_argument('--no-sandbox')
options.add_experimental_option('excludeSwitches', ['enable-automation'])
options.add_experimental_option('useAutomationExtension', False)

# %%
driver = webdriver.Edge(options=options)

# %%
driver.maximize_window()
driver.execute_cdp_cmd("Page.addScriptToEvaluateOnNewDocument", {
    "source": """
    Object.defineProperty(navigator, 'webdriver', {
        get: () => undefined
    })
    """
})
# Out:
# {'identifier': '2'}

# %%
driver.get('https://cvpr2023.thecvf.com/Conferences/2023/AcceptedPapers')

# %%
btn = driver.find_element(By.XPATH,"/html/body/main/div[2]/div/div/div/table/tbody/tr[2361]/td[1]/strong")

# %%
btn.text
# Out:
# 'OT-Filter: An Optimal Transport Filter for Learning With Noisy Labels'

# %%
title_list = []
withcode = 0
xpath_tmp = "/html/body/main/div[2]/div/div/div/table/tbody/tr[{}]/td[1]/"
for i in tqdm(range(3,2362)):
    xpath_id = xpath_tmp.format(i)
    try:
        btn = driver.find_element(By.XPATH,xpath_id+"a")
    except:
        btn = driver.find_element(By.XPATH,xpath_id+"strong")
    finally:
        title_list.append(btn.text)
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████| 2359/2359 [01:03<00:00, 37.00it/s]

# %%
xpath_id
# Out:
# '/html/body/main/div[2]/div/div/div/table/tbody/tr[2361]/td[1]/'

# %%
len(title_list)
# Out:
# 2359

# %%
title_list
# Out:
# ['SDFusion: Multimodal 3D Shape Completion, Reconstruction, and Generation',
#  'Spectral Bayesian Uncertainty for Image Super-Resolution',
#  'Revisiting Temporal Modeling for CLIP-Based Image-to-Video Knowledge Transferring',
#  'ViewNet: A Novel Projection-Based Backbone With View Pooling for Few-Shot Point Cloud Classification',
#  'Exploiting Completeness and Uncertainty of Pseudo Labels for Weakly Supervised Video Anomaly Detection',
#  'Post-Processing Temporal Action Detection',
#  'Learning Analytical Posterior Probability for Human Mesh Recovery',
#  'Learning Discriminative Representations for Skeleton Based Action Recognition',
#  'DejaVu: Conditional Regenerative Learning To Enhance Dense Prediction',
#  'Accidental Light Probes',
#  'Multi-Object Manipulation via Object-Centric Neural Scattering Functions',
#  'CFA: Class-Wise Calibrated Fair Adversarial Training',
#  'AutoAD: Movie Description in Context',
# ...

# %%
driver.close()

# %%
import json

# %%
with open("cvpr_2023_title.json", 'w') as  f:
    json.dump(title_list, f)

# %%
from wordcloud import (WordCloud, get_single_color_func, STOPWORDS, ImageColorGenerator)
import matplotlib.pyplot as plt

# %%
txt_stop = """a an . , : ? the is in to of via be from by with and or for - on"""

# %%
text_all = " ".join(title_list)

# %%
stop_words_list = txt_stop.split(" ")
stopwords = set(STOPWORDS)
for w in stop_words_list:
    stopwords.add(w)

# %%
wordcloud = WordCloud(
    background_color="white",
    width=1000, 
    height=860, 
    margin=2,
    max_font_size=196,
    max_words=256,
    random_state=96,
    stopwords=stopwords,
).generate(text_all.lower())

# %%
plt.imshow(wordcloud)
plt.axis("off")
plt.show()

# %%
wordcloud.to_file('wordcloud_cvpr2023_title.pdf')

# %%
from collections import Counter

# %%
wordcount = Counter([i.lower() for i in text_all.split(" ") if i.lower() not in stop_words_list])

# %%
wordcount
# Out:
# Counter({'learning': 445,
#          'image': 261,
#          '3d': 249,
#          'detection': 185,
#          'neural': 185,
#          'object': 176,
#          'segmentation': 164,
#          'video': 161,
#          'semantic': 120,
#          'models': 104,
#          'visual': 102,
#          'estimation': 97,
#          'generation': 93,
#          'diffusion': 93,
#          'representation': 90,
#          'point': 89,
#          'transformer': 88,
#          'reconstruction': 86,
#          'efficient': 84,
#          'network': 78,
#          'recognition': 77,
#          'model': 77,
#          'human': 76,
#          'towards': 76,
#          'domain': 76,
#          'using': 73,
#          'scene': 70,
#          'fields': 68,
#          'self-supervised': 67,
#          'deep': 67,
#          'pose': 65,
#          'vision': 62,
#          'cloud': 59,
#          'masked': 59,
#          'radiance': 59,
#          'contrastive': 59,
#          'synthesis': 59,
# ...
